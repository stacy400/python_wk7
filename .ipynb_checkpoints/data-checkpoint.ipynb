# %%
import pandas as pd
import numpy as np
df = pd.read_csv('Covid Data.csv')
df.head(10)
# Out:
#    USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE   DATE_DIED  INTUBED  PNEUMONIA  \
# 0      2             1    1             1  03/05/2020       97          1
# 1      2             1    2             1  03/06/2020       97          1
# 2      2             1    2             2  09/06/2020        1          2
# 3      2             1    1             1  12/06/2020       97          2
# 4      2             1    2             1  21/06/2020       97          2
# 5      2             1    1             2  9999-99-99        2          1
# 6      2             1    1             1  9999-99-99       97          2
# 7      2             1    1             1  9999-99-99       97          1
# 8      2             1    1             2  9999-99-99        2          2
# 9      2             1    1             2  9999-99-99        2          2
#
#    AGE  PREGNANT  DIABETES  ...  ASTHMA  INMSUPR  HIPERTENSION  OTHER_DISEASE  \
# ...

# %%
df.isnull().sum()
# Out:
# USMER                   0
# MEDICAL_UNIT            0
# SEX                     0
# PATIENT_TYPE            0
# DATE_DIED               0
# INTUBED                 0
# PNEUMONIA               0
# AGE                     0
# PREGNANT                0
# DIABETES                0
# COPD                    0
# ASTHMA                  0
# INMSUPR                 0
# HIPERTENSION            0
# OTHER_DISEASE           0
# CARDIOVASCULAR          0
# OBESITY                 0
# RENAL_CHRONIC           0
# TOBACCO                 0
# CLASIFFICATION_FINAL    0
# ICU                     0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 21 columns):
#  #   Column                Non-Null Count    Dtype
# ---  ------                --------------    -----
#  0   USMER                 1048575 non-null  int64
#  1   MEDICAL_UNIT          1048575 non-null  int64
#  2   SEX                   1048575 non-null  int64
#  3   PATIENT_TYPE          1048575 non-null  int64
#  4   DATE_DIED             1048575 non-null  object
#  5   INTUBED               1048575 non-null  int64
#  6   PNEUMONIA             1048575 non-null  int64
#  7   AGE                   1048575 non-null  int64
#  8   PREGNANT              1048575 non-null  int64
#  9   DIABETES              1048575 non-null  int64
#  10  COPD                  1048575 non-null  int64
#  11  ASTHMA                1048575 non-null  int64
#  12  INMSUPR               1048575 non-null  int64
#  13  HIPERTENSION          1048575 non-null  int64
# ...

# %% [markdown]
# # Task2

# %%
df.describe()
# Out:
#               USMER  MEDICAL_UNIT           SEX  PATIENT_TYPE       INTUBED  \
# count  1.048575e+06  1.048575e+06  1.048575e+06  1.048575e+06  1.048575e+06
# mean   1.632194e+00  8.980565e+00  1.499259e+00  1.190765e+00  7.952288e+01
# std    4.822084e-01  3.723278e+00  4.999997e-01  3.929041e-01  3.686889e+01
# min    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# 25%    1.000000e+00  4.000000e+00  1.000000e+00  1.000000e+00  9.700000e+01
# 50%    2.000000e+00  1.200000e+01  1.000000e+00  1.000000e+00  9.700000e+01
# 75%    2.000000e+00  1.200000e+01  2.000000e+00  1.000000e+00  9.700000e+01
# max    2.000000e+00  1.300000e+01  2.000000e+00  2.000000e+00  9.900000e+01
#
#           PNEUMONIA           AGE      PREGNANT      DIABETES          COPD  \
# count  1.048575e+06  1.048575e+06  1.048575e+06  1.048575e+06  1.048575e+06
# mean   3.346831e+00  4.179410e+01  4.976558e+01  2.186404e+00  2.260569e+00
# ...

# %%
df.groupby("SEX")["AGE"].mean()
# Out:
# SEX
# 1    41.315198
# 2    42.274428
# Name: AGE, dtype: float64

# %%
df.groupby("ICU")["AGE"].mean()
# Out:
# ICU
# 1     51.646340
# 2     53.271401
# 97    39.206699
# 99    43.536592
# Name: AGE, dtype: float64

# %%
cols = ["DATE_DIED"] + [col for col in df.columns if col != "DATE_DIED"]
df = df[cols]
df
# Out:
#           DATE_DIED  USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE  INTUBED  \
# 0        03/05/2020      2             1    1             1       97
# 1        03/06/2020      2             1    2             1       97
# 2        09/06/2020      2             1    2             2        1
# 3        12/06/2020      2             1    1             1       97
# 4        21/06/2020      2             1    2             1       97
# ...             ...    ...           ...  ...           ...      ...
# 1048570  9999-99-99      2            13    2             1       97
# 1048571  9999-99-99      1            13    2             2        2
# 1048572  9999-99-99      2            13    2             1       97
# 1048573  9999-99-99      2            13    2             1       97
# 1048574  9999-99-99      2            13    2             1       97
#
#          PNEUMONIA  AGE  PREGNANT  DIABETES  ...  ASTHMA  INMSUPR  \
# 0                1   65         2         2  ...       2        2
# ...

# %%
# Line Chart: Deaths over Time
import matplotlib.pyplot as plt
deaths_over_time = df["DATE_DIED"].value_counts().sort_index()
plt.figure(figsize=(10,6))
plt.plot(deaths_over_time.index, deaths_over_time.values, color="red", marker="o", label="Deaths")
plt.title("COVID-19 Deaths Over Time")
plt.xlabel("Date")
plt.ylabel("Number of Deaths")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
#Bar Chart: Average Age by Patient Type
avg_age = df.groupby("PATIENT_TYPE")["AGE"].mean()
plt.figure(figsize=(7,5))
avg_age.plot(kind="bar", color="blue")
plt.title("Average Age by Patient Type")
plt.xlabel("Patient Type")
plt.ylabel("Average Age")
plt.xticks(rotation=0)
plt.show()

# %%
#Histogram: Age Distribution
plt.figure(figsize=(8,5))
plt.hist(df["AGE"].dropna(), bins=20, color="purple", edgecolor="black")
plt.title("Age Distribution of Patients")
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.grid(axis="y")
plt.show()

# %%
#Scatter Plot: Age vs ICU Admission
import matplotlib.pyplot as plt
plt.figure(figsize=(8,5))
plt.scatter(df["AGE"], df["ICU"], color="green", alpha=0.5)
plt.title("Age vs ICU Admission")
plt.xlabel("Age")
plt.ylabel("ICU Status (Admitted / Not admitted)")
plt.grid(True)
plt.show()
